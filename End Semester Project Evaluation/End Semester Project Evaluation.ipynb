# %%
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
pd.set_option('max_colwidth', 100)

# %% [markdown]
# # Data Preprocessing

# %%
from nltk.stem.porter import PorterStemmer

stemmer = PorterStemmer()

def preprocess(document):
    """ This function Changes document to lowercase and removes stopwords"""
    document = str(document)
    document = document.lower()
    words = word_tokenize(document)
    
    words = [word for word in words if word not in stopwords.words('english')]
    
    document = " ".join(words)
    return document

# %% [markdown]
# ## Creating Tf-Idf model for our dataset

# %%
# loading data
dataset = pd.read_csv('dataset.csv')
dataset.head()
# Out:
#                                                                                              questions  \
# 0  The ratio of mass percent of C and H of anorganic compound (CXHYOZ) is 6 : 1 Ifone molecule of t...
# 1                         Which type of ‘defect’ has the presence ofcations in the interstitial sites
# 2           According to molecular orbital theorywhich of the following will not be a viable molecule
# 3  Which of the following lines correctly showthe temperature dependence ofequilibrium constant  K ...
# 4  The combustion of benzene (l) gives CO2(g)and H2O(l) Given that heat of combustionof benzene at ...
#
#      year                 topic
# 0  2018.0                alkane
# 1  2018.0           solid state
# 2  2018.0      chemical_bonding
# 3  2018.0  chemical_equilibrium
# 4  2018.0        thermodynamics

# %%
# extracting the question from dataframe
dataset = dataset.dropna()
dataset['year'] = dataset['year'].astype(np.int64)

questions = [question for question in dataset.questions]
dataset.head()
# Out:
#                                                                                              questions  \
# 0  The ratio of mass percent of C and H of anorganic compound (CXHYOZ) is 6 : 1 Ifone molecule of t...
# 1                         Which type of ‘defect’ has the presence ofcations in the interstitial sites
# 2           According to molecular orbital theorywhich of the following will not be a viable molecule
# 3  Which of the following lines correctly showthe temperature dependence ofequilibrium constant  K ...
# 4  The combustion of benzene (l) gives CO2(g)and H2O(l) Given that heat of combustionof benzene at ...
#
#    year                 topic
# 0  2018                alkane
# 1  2018           solid state
# 2  2018      chemical_bonding
# 3  2018  chemical_equilibrium
# 4  2018        thermodynamics

# %%
print(questions)
# Out:
# ['The ratio of mass percent of C and H of anorganic compound (CXHYOZ) is 6 : 1 Ifone molecule of the above compound(CXHYOZ) contains half as much oxygenas required to burn one molecule ofcompound CXHY completely to CO2 andH2O The empirical formula of compoundCXHYOZ is', 'Which type of ‘defect’ has the presence ofcations in the interstitial sites ', 'According to molecular orbital theorywhich of the following will not be a viable molecule ', 'Which of the following lines correctly showthe temperature dependence ofequilibrium constant  K  for an exothermicreaction ', 'The combustion of benzene (l) gives CO2(g)and H2O(l) Given that heat of combustionof benzene at constant volume is−32639 kJ mol−1 at 258 C; heat ofcombustion (in kJ mol−1) of benzene atconstant pressure will be :(R=8314 JK−1 mol−1)', 'For 1 molal aqueous solution of thefollowing compounds which one willshow the highest freezing point ', 'An aqueous solution contains 010 M H2Sand 020 M HCl If the equilibriumconstants for the formation of HS− from H2S is 10×10−7 and that of S2− fromHS− ions is 12×10−13 then theconcentration of S2− ions in aqueoussolution is', ' An aqueous solution contains an unknownconcentration of Ba2+ When 50 mL of a1 M solution of Na2SO4 is added BaSO4just begins to precipitate The final volumeis 500 mL The solubility product of BaSO4is 1×10−10 What is the originalconcentration of Ba2+ ', 'At 5188 C the rate of decomposition of asample of gaseous acetaldehyde initiallyat a pressure of 363 Torr was100 Torr s−1 when 5% had reacted and05 Torr s−1 when 33% had reacted Theorder of the reaction is', 'How long (approximate) should water beelectrolysed by passing through100 amperes current so that the oxygenreleased can completely burn 2766 g ofdiborane (Atomic weight of B=108 u)', 'The recommended concentration offluoride ion in drinking water is up to1 ppm as fluoride ion is required to maketeeth enamel harder by converting[3Ca3(PO4)2⋅Ca(OH)2] to', 'Which of the following compoundscontain(s) no covalent bond(s) KCl PH3 O2 B2H6 H2SO4', 'Which of the following are Lewis acids ', 'Total number of lone pair of electrons in 3I− ion is', 'Which of the following salts is the mostbasic in aqueous solution', 'Hydrogen peroxide oxidises [Fe(CN)6]4−to [Fe(CN)6]3− in acidic medium butreduces [Fe(CN)6]3− to [Fe(CN)6]4− inalkaline medium The other productsformed are respectively', 'The oxidation states ofCr in [Cr(H2O)6]Cl3 [Cr(C6H6)2] andK2[Cr(CN)2(O)2(O2)(NH3)] respectively are', 'When metal ‘M’ is treated with NaOH awhite gelatinous precipitate ‘X’ is obtainedwhich is soluble in excess of NaOHCompound ’X’ when heated strongly givesan oxide which is used in chromatographyas an adsorbent The metal ‘M’ is', 'Consider the following reaction andstatements : [Co(NH3)4Br2]++Br−→[Co(NH3)3Br3]+NH3(I) Two isomers are produced if thereactant complex ion is a cis-isomer(II) Two isomers are produced if thereactant complex ion is a transisomer(III) Only one isomer is produced if thereactant complex ion is a transisomer(IV) Only one isomer is produced if thereactant complex ion is a cis-isomerThe correct statements are', 'Glucose on prolonged heating with HI gives', 'The trans-alkenes are formed by thereduction of alkynes with', 'Which of the following compounds willbe suitable for Kjeldahl’s method for nitrogen estimation', 'Phenol on treatment with CO2 in thepresence of NaOH followed byacidification produces compound X as themajor product X on treatment with(CH3CO)2O in the presence of catalyticamount of H2SO4 produces', 'An alkali is titrated against an acid withmethyl orange as indicator which of thefollowing is a correct combination', 'The predominant form of histaminepresent in human blood is (pKaHistidine=60)', 'Phenol reacts with methyl chloroformatein the presence of NaOH to form productA A reacts with Br2 to form product BA and B are respectively', 'The increasing order of basicity of the following compounds is', 'The major product formed in the following reaction is  ...

# %%
# preprocess questions using the preprocess function
questions = [preprocess(question) for question in questions]
print(questions)
# Out:
# ['ratio mass percent c h anorganic compound ( cxhyoz ) 6 : 1 ifone molecule compound ( cxhyoz ) contains half much oxygenas required burn one molecule ofcompound cxhy completely co2 andh2o empirical formula compoundcxhyoz', 'type ‘ defect ’ presence ofcations interstitial sites', 'according molecular orbital theorywhich following viable molecule', 'following lines correctly showthe temperature dependence ofequilibrium constant k exothermicreaction', 'combustion benzene ( l ) gives co2 ( g ) h2o ( l ) given heat combustionof benzene constant volume is−32639 kj mol−1 258 c ; heat ofcombustion ( kj mol−1 ) benzene atconstant pressure : ( r=8314 jk−1 mol−1 )', '1 molal aqueous solution thefollowing compounds one willshow highest freezing point', 'aqueous solution contains 010 h2sand 020 hcl equilibriumconstants formation hs− h2s 10×10−7 s2− fromhs− ions 12×10−13 theconcentration s2− ions aqueoussolution', 'aqueous solution contains unknownconcentration ba2+ 50 ml a1 solution na2so4 added baso4just begins precipitate final volumeis 500 ml solubility product baso4is 1×10−10 originalconcentration ba2+', '5188 c rate decomposition asample gaseous acetaldehyde initiallyat pressure 363 torr was100 torr s−1 5 % reacted and05 torr s−1 33 % reacted theorder reaction', 'long ( approximate ) water beelectrolysed passing through100 amperes current oxygenreleased completely burn 2766 g ofdiborane ( atomic weight b=108 u )', 'recommended concentration offluoride ion drinking water to1 ppm fluoride ion required maketeeth enamel harder converting [ 3ca3 ( po4 ) 2⋅ca ( oh ) 2 ]', 'following compoundscontain ( ) covalent bond ( ) kcl ph3 o2 b2h6 h2so4', 'following lewis acids', 'total number lone pair electrons 3i− ion', 'following salts mostbasic aqueous solution', 'hydrogen peroxide oxidises [ fe ( cn ) 6 ] 4−to [ fe ( cn ) 6 ] 3− acidic medium butreduces [ fe ( cn ) 6 ] 3− [ fe ( cn ) 6 ] 4− inalkaline medium productsformed respectively', 'oxidation states ofcr [ cr ( h2o ) 6 ] cl3 [ cr ( c6h6 ) 2 ] andk2 [ cr ( cn ) 2 ( ) 2 ( o2 ) ( nh3 ) ] respectively', 'metal ‘ ’ treated naoh awhite gelatinous precipitate ‘ x ’ obtainedwhich soluble excess naohcompound ’ x ’ heated strongly givesan oxide used chromatographyas adsorbent metal ‘ ’', 'consider following reaction andstatements : [ co ( nh3 ) 4br2 ] ++br−→ [ co ( nh3 ) 3br3 ] +nh3 ( ) two isomers produced thereactant complex ion cis-isomer ( ii ) two isomers produced thereactant complex ion transisomer ( iii ) one isomer produced thereactant complex ion transisomer ( iv ) one isomer produced thereactant complex ion cis-isomerthe correct statements', 'glucose prolonged heating hi gives', 'trans-alkenes formed thereduction alkynes', 'following compounds willbe suitable kjeldahl ’ method nitrogen estimation', 'phenol treatment co2 thepresence naoh followed byacidification produces compound x themajor product x treatment ( ch3co ) 2o presence catalyticamount h2so4 produces', 'alkali titrated acid withmethyl orange indicator thefollowing correct combination', 'predominant form histaminepresent human blood ( pkahistidine=60 )', 'phenol reacts methyl chloroformatein presence naoh form producta reacts br2 form product ba b respectively', 'increasing order basicity following compounds', 'major product formed following reaction', 'major product following reaction']

# %%
# bag of word model
vectorizer = TfidfVectorizer()
tfidf_model = vectorizer.fit_transform(questions)

# %%
tfidf = pd.DataFrame(tfidf_model.toarray(), columns = vectorizer.get_feature_names())
print(tfidf)
# Out:
#          010       020        10       108        12        13       258  \
# 0   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.156491
# 5   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6   0.182775  0.182775  0.488367  0.000000  0.182775  0.182775  0.000000
# 7   0.000000  0.000000  0.331027  0.000000  0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.000000  0.254991  0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 12  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 13  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 15  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 16  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 18  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 19  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 20  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 21  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 22  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 23  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 24  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 25  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 26  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 27  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 28  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#         2766        2o     32639  ...      used    viable    volume  volumeis  \
# 0   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.000000  ...  0.000000  0.405382  0.000000  0.000000
# 3   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.156491  ...  0.000000  0.000000  0.156491  0.000000
# 5   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.185834
# 8   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 9   0.254991  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 12  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 13  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 15  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 16  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.000000  ...  0.226721  0.000000  0.000000  0.000000
# 18  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 19  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 20  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 21  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 22  0.000000  0.224403  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 23  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 24  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 25  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 26  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 27  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 28  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
#
#       was100     water    weight    willbe  willshow  withmethyl
# 0   0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 1   0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 2   0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 3   0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 4   0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 5   0.000000  0.000000  0.000000  0.000000  0.348174    0.000000
# 6   0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 7   0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 8   0.194772  0.000000  0.000000  0.000000  0.000000    0.000000
# 9   0.000000  0.227108  0.254991  0.000000  0.000000    0.000000
# 10  0.000000  0.203100  0.000000  0.000000  0.000000    0.000000
# 11  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 12  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 13  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 14  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 15  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 16  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 17  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 18  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 19  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 20  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 21  0.000000  0.000000  0.000000  0.379241  0.000000    0.000000
# 22  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 23  0.000000  0.000000  0.000000  0.000000  0.000000    0.341265
# 24  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 25  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 26  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 27  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
# 28  0.000000  0.000000  0.000000  0.000000  0.000000    0.000000
#
# [29 rows x 271 columns]

# %%
for col in tfidf.columns:
    print(col)
# Out:
# 010
# 020
# 10
# 108
# 12
# 13
# 258
# 2766
# 2o
# 32639
# 33
# 363
# 3br3
# 3ca3
# 3i
# 4br2
# 50
# 500
# 5188
# 60
# 8314
# a1
# according
# acetaldehyde
# acid
# acidic
# acids
# added
# adsorbent
# alkali
# alkenes
# alkynes
# amperes
# and05
# andh2o
# andk2
# andstatements
# anorganic
# approximate
# aqueous
# aqueoussolution
# asample
# atconstant
# atomic
# awhite
# b2h6
# ba
# ba2
# basicity
# baso4is
# baso4just
# beelectrolysed
# begins
# benzene
# blood
# bond
# br
# br2
# burn
# butreduces
# byacidification
# c6h6
# ca
# catalyticamount
# ch3co
# chloroformatein
# chromatographyas
# cis
# cl3
# cn
# co
# co2
# combination
# combustion
# combustionof
# completely
# complex
# compound
# compoundcxhyoz
# compounds
# compoundscontain
# concentration
# consider
# constant
# contains
# converting
# correct
# correctly
# covalent
# cr
# current
# cxhy
# cxhyoz
# decomposition
# defect
# dependence
# drinking
# electrons
# empirical
# enamel
# equilibriumconstants
# estimation
# excess
# exothermicreaction
# fe
# final
# fluoride
# followed
# following
# form
# formation
# formed
# formula
# freezing
# fromhs
# gaseous
# gelatinous
# given
# gives
# givesan
# glucose
# h2o
# h2s
# h2sand
# h2so4
# half
# harder
# hcl
# heat
# heated
# heating
# hi
# highest
# histaminepresent
# hs
# human
# hydrogen
# ifone
# ii
# iii
# inalkaline
# increasing
# indicator
# initiallyat
# interstitial
# ion
# ions
# is
# isomer
# isomers
# isomerthe
# iv
# jk
# kcl
# kj
# kjeldahl
# lewis
# lines
# lone
# long
# major
# maketeeth
# mass
# medium
# metal
# method
# methyl
# ml
# mol
# molal
# molecular
# molecule
# mostbasic
# much
# na2so4
# naoh
# naohcompound
# nh3
# nitrogen
# number
# o2
# obtainedwhich
# ofcations
# ofcombustion
# ofcompound
# ofcr
# ofdiborane
# ofequilibrium
# offluoride
# oh
# one
# orange
# orbital
# order
# originalconcentration
# oxidation
# oxide
# oxidises
# oxygenas
# oxygenreleased
# pair
# passing
# percent
# peroxide
# ph3
# phenol
# pkahistidine
# po4
# point
# ppm
# precipitate
# predominant
# presence
# pressure
# produced
# produces
# product
# producta
# productsformed
# prolonged
# rate
# ratio
# reacted
# reaction
# reacts
# recommended
# required
# respectively
# s2
# salts
# showthe
# sites
# solubility
# soluble
# solution
# statements
# states
# strongly
# suitable
# temperature
# theconcentration
# thefollowing
# themajor
# theorder
# theorywhich
# thepresence
# thereactant
# thereduction
# through100
# titrated
# to
# to1
# torr
# total
# trans
# transisomer
# treated
# treatment
# two
# type
# unknownconcentration
# used
# viable
# volume
# volumeis
# was100
# water
# weight
# willbe
# willshow
# withmethyl
